# %% [markdown]
# # Assignment: Complete the Snippet

# %% [markdown]
# Shubh started building a basic Python Script which goes through the entire text of a particular book and mugs up all its words. After that it asks you for a word, goes over the times when this word came in the text and gives you the complete sentence in which it was used. You may choose to ask for as many such sentences as the number of occurences of the word.
#
# He's managed to come up with the part where he loads the file into Memory. He also managed to come up with snippets of code which could potentially do something if completed, but he has many deadlines to look after and not enough caffeine to turn to code. Can you help him?

# %%
File = open("HarryPotterAndTheSorcerersStone.txt",'r', encoding = 'utf-8')     #This helps in opening the file which is to be read

# %% [markdown]
# Next he makes a list of all the words present in the novel mapping them to their index(position) in the list of words (i.e. ListOfWords). This is done by mapping every word (a string) to a list (list of indices), and this is stored as a Dictionary (DictionaryoOfWords)
#
#
#
# He makes use of the readlines() method which is used to extract all the lines from any text and the split() function which could be used to split any sentence into distinct words. The replace() method is used on strings to replace certain segments of the string with something else.

# %%
DictionaryOfWords = {}         #Dictionary mapping every word to a list (of indices of the words' occurences)
Novel = []                     #List of all words in the order, in which they appear!



i = 0                   #Counter Variable to keep track of index of words

for line in File.readlines():     #Iterate over all lines present in the text
    
    #Look at Python's Conciseness!
    
    line = line.replace(".","").replace(",","").replace('?','').replace('!','').replace('[','').replace(']','')\
    .replace('(','').replace(')','').replace('%','').replace('/','')
      
    #COMPLETE THE CODE FROM HERE:
    
    #This would split the line into many different words, and iterate over these words
    
    
    for word in line.split(' '): 
                                                                             
        if word in DictionaryOfWords.keys():     #If the word is already present in the dictionary
                                                                             
            DictionaryOfWords[word]=i        #Add the index into the pre-existing list for this word
                                                                             
        else:
            DictionaryOfWords[word]=i         #Create a new list of indices for this word, with a single element
                                                                               
        
        Novel.append(word)        #Add the Word in the Novel's ordered list of words
                                                                             
        i+=1
print(DictionaryOfWords)
# Out:
# {'c': 84191, 'H': 90807, 'A': 90564, 'P': 84443, 'I': 90915, 'U': 84197, 'ONE\n': 4656, '\n': 90913, '4': 90814, '*\n': 90816, 'They': 90375, 'didn’t': 90587, 'think': 88836, 'they': 90920, 'could': 90909, 'bear': 88127, 'it': 90761, 'if': 90141, 'anyone': 90908, 'found': 90426, 'out': 90594, 'about': 89424, 'the\n': 90603, 'Potters': 61315, 'Mrs': 90847, 'Potter': 89931, 'was': 90927, 'Dursley’s': 5043, 'sister': 90706, 'but': 90707, 'hadn’t': 90262, 'met\n': 85270, 'for': 90873, 'several': 83973, 'years;': 41, 'in': 90789, 'fact': 89518, 'Dursley': 16808, 'pretended': 41360, 'she': 90744, 'have': 90946, 'a\n': 89464, 'because': 88147, 'her': 89879, 'and': 90919, 'good-for-nothing': 57, 'husband': 58, 'were': 90921, 'as\n': 90040, 'unDursleyish': 61, 'as': 90639, 'possible': 65994, 'to': 90945, 'be': 90843, 'The': 90010, 'Dursleys': 79417, 'shuddered': 70, 'to\n': 90938, 'what': 88666, 'the': 90924, 'neighbors': 75, 'would': 90314, 'say': 89200, 'arrived': 89531, 'street': 22654, 'knew': 90254, 'that': 90907, 'had': 90395, 'a': 90947, 'small': 86002, 'son': 87914, 'too': 90397, 'but\n': 88475, 'never': 90315, 'even': 90162, 'seen': 89794, 'him': 90826, 'This': 90266, 'boy': 87188, 'another': 89037, 'good': 90896, 'reason\n': 108, 'keeping': 71988, 'away;': 113, 'want': 88985, 'Dudley': 90952, 'mixing': 40736, 'with\n': 77143, 'child': 3938, 'like': 89775, 'that\n': 90926, 'When': 89481, 'Mr': 90054, 'woke': 77556, 'up': 90859, 'on': 90516, 'dull': 51002, 'gray': 58742, 'Tuesday\n': 136, 'our': 90046, 'story': 88529, 'starts': 89600, 'there': 90695, 'nothing': 90763, 'cloudy': 70266, 'sky': 77603, 'outside': 90060, 'suggest': 88286, 'strange': 88533, 'mysterious': 59797, 'things': 87997, 'soon': 69657, 'happen¬\n': 158, 'ing': 90901, 'all': 90864, 'over': 90929, 'country': 26703, 'hummed': 87423, 'he': 90696, 'picked': 84333, 'his\n': 89099, 'most': 88852, 'boring': 39061, 'tie': 174, 'work': 88121, 'gossiped': 180, 'away': 85997, 'happily\n': 182, 'wrestled': 185, 'screaming': 60930, 'into': 90521, 'his': 90930, 'high': 86919, 'chair\n': 24232, 'None': 194, 'of': 90949, 'them': 90653, 'noticed': 83078, 'large': 82280, 'tawny': 200, 'owl': 90788, 'flutter': 77595, 'past': 90506, 'window\n': 69533, 'At': 89840, 'half': 86924, 'eight': 36805, 'briefcase': 216, 'pecked\n': 217, 'cheek': 40712, 'tried': 89513, 'kiss': 28604, 'good-bye': 72740, 'missed': 27050, 'now': 89974, 'having': 70383, 'tantrum': 7767, 'throwing\n': 239, 'cereal': 241, 'at': 90941, 'walls': 81768, '“Little': 6263, 'tyke”': 246, 'chortled': 48400, 'left\n': 83300, 'house': 69216, 'He': 90866, 'got': 90863, 'car': 26447, 'backed': 60671, 'number': 83706, 'four’s\n': 265, 'drive\n': 266, 'It': 90770, 'corner': 90430, 'first': 90357, 'sign': 87865, 'of\n': 90616, 'something': 90630, 'peculiar': 35848, '—': 90894, 'cat': 41432, 'reading': 31126, 'map': 72599, 'For': 87197, 'second': 86370, 'Mr\n': 746, 'realize': 89028, 'then': 88316, 'jerked': 45873, 'head\n': 87602, 'around': 88472, 'look': 90632, 'again': 89137, 'There': 85301, 'tabby': 4894, 'standing': 90059, 'corner\n': 320, '*': 90801, '4\n': 90802, 'T': 84445, 'BOY': 4957, 'WHO': 4958, 'LIVED\n': 4959, 'Privet': 56899, 'Drive': 56900, 'wasn’t': 90709, 'sight': 90837, 'What': 89565, 'he\n': 90313, 'been': 89570, 'thinking': 87437, 'must': 90842, 'trick': 61037, 'light': 82564, 'blinked': 86782, 'stared': 86823, 'back': 90872, 'As': 89056, 'Durs-\n': 14431, 'ley': 54513, 'drove': 12654, 'road': 36854, 'watched': 85978, 'in\n': 90792, 'mirror': 88848, 'said': 90917, 'no\n': 87863, 'looking': 90832, 'sign;': 415, 'cats': 62068, 'couldn’t': 90407, 'read': 83970, 'maps': 419, 'or': 90307, 'signs': 421, 'Dursley\n': 1966, 'gave': 89313, 'himself': 84725, 'little': 90175, 'shake': 77527, 'put': 90148, 'mind': 88633, 'toward': 90643, 'town': 19214, 'thought': 90067, 'except': 77066, 'order': 87285, 'drills': 1110, 'hoping': 79676, 'get': 90560, 'day\n': 67666, 'But': 87709, 'edge': 85515, 'driven': 62704, 'by\n': 8 ...

# %% [markdown]
# That guy truly left a lot of work for you!
#
# Now that you've done that, We have the words in the novel alongwith where they appeared in the text loaded into memory (Thanks to You!).
#
# The Next Step would be to answer any queries the user may have.
#
# To do this, we define the function GetQuery() which returns the word as well as the number of results the user wants to see (as a tuple):

# %%
#COMPLETE THE CODE FROM HERE:

def GetQuery():
   
    word = input("Enter query word: ")        #Get Input from the user regarding what word s/he wants to query for

    Number =  int(input("Enter no. of results: "))     #Get Input from the user regarding how many results the user wants to see

    return (word,Number)                 #Return as output a tuple of the word and the Number of results

# %% [markdown]
# Now, We need a function which takes as input the index of any particular word and prints the words surrounding it as if they were in an actual sentence.
#
# This is done by iterating over the words surrounding it, and printing them with gaps in between. We also assume that this occurence isn't a boundary case and thus, the 10 words surronding it actually exist.

# %%
def PrintContext(index):
    
    global Novel                          #Declares the list Novel as a Global Variable
    
    #COMPLETE THE CODE FROM HERE:
    
    for i in range(10) :           #Define the range so that the task above is fulfilled
        
        print(Novel[index-i:index+i], end = '')          #Print the word (using List Indexing) with a space after that
        i+=1
    print('\n')

# %% [markdown]
# The result of the GetQuery() function will be passed into a second function which would take as input the word and the number of results to be displayed and do so!

# %%
def PrintResult(word, NumQuery):
  
    global DictionaryOfWords                #Allows us to use the Dictionary as a global variable
    
    #COMPLETE THE CODE FROM HERE:
    L = DictionaryOfWords 
    
    for i in range(0,min(len(L),NumQuery)):
        
        PrintContext(DictionaryOfWords[word])             #Actually print the words surrounding the ith occurence of the given word

# %% [markdown]
# Finally, you need an infinite loop which runs until the user wants it to and asks for the next word (if the user wants to query more) or end the loop.

# %%
while 1>0 :   
    
    Choice = input("Press Y in order to Continue with the next query or N to end./\ Please press Enter after entering your choice!")
    
    #COMPLETE THE CODE FROM HERE:
    
    if Choice == "Y" :                     # If the user wants to query 
        
        search= GetQuery()
        search_word = search[0]
        search_index = Novel.index(search_word)
        print(search_index)
        PrintResult(search[0],search[1])             #Use some of the past defined function to do so
        
        
    else:
        
        break                                 #Else end the loop
# Out:
# Press Y in order to Continue with the next query or N to end./\ Please press Enter after entering your choice!Y
# Enter query word: Dursley
# Enter no. of results: 3
# 45
# []['you', 'Dursley']['warning', 'you', 'Dursley', '—']['“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n']['said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning']['he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you']['sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—']['a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one']['like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more']['Vernon', 'like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more', 'word']
#
# []['you', 'Dursley']['warning', 'you', 'Dursley', '—']['“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n']['said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning']['he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you']['sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—']['a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one']['like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more']['Vernon', 'like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more', 'word']
#
# []['you', 'Dursley']['warning', 'you', 'Dursley', '—']['“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n']['said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning']['he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you']['sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—']['a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one']['like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more']['Vernon', 'like', 'a', 'sword', 'he', 'said', '“I’m', 'warning', 'you', 'Dursley', '—', 'I’m\n', 'warning', 'you', '—', 'one', 'more', 'word']
